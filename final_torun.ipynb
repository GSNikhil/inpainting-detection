# %% [markdown]
# # Load Libraries

# %%
# # Uncomment to install PyWavelets and dtcwt
# !pip3 install PyWavelets
# !pip3 install dtcwt

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import cv2
from PIL import Image
import os

# For semantic segmentation
import torch
import torchvision
from torchvision import transforms
from torchvision.models.segmentation import DeepLabV3_ResNet50_Weights

from skimage import io, color, img_as_float
from scipy.ndimage import gaussian_filter

from skimage.morphology import opening, closing, disk
from skimage import io, color, img_as_float, morphology
from scipy.ndimage import gaussian_filter
from scipy import ndimage as ndi

import pywt
import dtcwt
import csv
import pickle

print(np.__version__)
# Out:
# 1.26.4

# %% [markdown]
# # Image Read

# %%
# read image of any format - png, bmp, jpg and return the rgb image as numpy array
# normalize the image to [0, 1] range
def read_img(image_path):
    img = Image.open(image_path)
    img = np.array(img)
    img = img / 255.0
    return img

# %% [markdown]
# # Segmentation - KMeans and Semantic

# %%
def kmeans(img, n_clusters, display=False):
    data = img.reshape((-1, 1))
    H, W = img.shape

    kmeans = KMeans(n_clusters=n_clusters, n_init='auto')
    clusters = kmeans.fit_predict(data)
    clusters = clusters.reshape((H, W))

    if display:
        plt.imshow(clusters, cmap="Spectral")
        plt.title(f"Input Image Segmentation, n_clusters: {n_clusters}")
        plt.axis('off')
        plt.show()

    return clusters

# %%
def simple_segmentation(image, n_clusters=5, feature_space='rgb', smoothing_sigma=1,display=False):
    """
    Perform simple image segmentation using K-means clustering.

    Parameters:
    - image: Input image as a NumPy array.
    - n_clusters: The desired number of clusters (segments).
    - feature_space: The color space to use ('rgb' or 'lab').

    Returns:
    - labels: A 2D array of the same height and width as the image, containing the segment labels.
    """
    # Convert image to float representation
    image = img_as_float(image)
    h, w, c = image.shape

    # Apply image smoothing to reduce noise
    smoothed_image = gaussian_filter(image, sigma=(smoothing_sigma, smoothing_sigma, 0))

    # Choose feature space
    if feature_space == 'lab':
        # Convert to Lab color space for better perceptual similarity
        image_feats = color.rgb2lab(smoothed_image)
    else:
        # Use RGB color space
        image_feats = smoothed_image

    # Reshape the image to a 2D array of pixels and color features
    X = image_feats.reshape((-1, c))

    # Perform K-means clustering
    print("Performing K-means clustering...")
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(X)
    labels = kmeans.labels_

    # Reshape labels back to image dimensions
    labels = labels.reshape((h, w))

    # Apply improved morphological operations to clean up small regions
    selem = morphology.disk(5)
    labels_cleaned = np.zeros_like(labels)
    min_size = 500  # Adjust this value based on image size

    for i in range(n_clusters):
        mask = (labels == i).astype(np.bool_)
        mask_filled = ndi.binary_fill_holes(mask)
        mask_cleaned = morphology.remove_small_objects(mask_filled, min_size=min_size)
        mask_smooth = morphology.closing(mask_cleaned, selem)
        mask_smooth = morphology.opening(mask_smooth, selem)
        labels_cleaned[mask_smooth] = i

    if display:
        plt.imshow(labels_cleaned, cmap='tab20')
        plt.axis('off')
        plt.title('Segmentation Result')
        plt.show()

    return labels_cleaned

# %% [markdown]
# # Band Processing

# %%
# Performs Log Normalization and z-tranforms and clips data [-1, 2] range
def normalize_coeffs(bands):
    reals = []
    imags = []
    for band in range(bands.shape[-1]):
        real_coeffs = bands[:, :, band].real
        imag_coeffs = bands[:, :, band].imag

        # Normalize
        # Log (1+x) transform
        eps = 1e-8
        real_coeffs = np.log10((real_coeffs) + abs(real_coeffs.min()) + eps)
        imag_coeffs = np.log10((imag_coeffs) + abs(imag_coeffs.min()) + eps)

        # Z-Scaling
        real_coeffs = (real_coeffs - real_coeffs.mean()) / (real_coeffs.std() + 1e-8)
        imag_coeffs = (imag_coeffs - imag_coeffs.mean()) / (imag_coeffs.std() + 1e-8)

        reals.append(real_coeffs)
        imags.append(imag_coeffs)

    return np.asarray(reals), np.asarray(imags)

# %%
def display_wavelet_coeffs(reals, imags, img_id, display=False, savepath=""):
    # Clip the data to [-1, 2] range
    reals = np.clip(reals, -1, 2)
    imags = np.clip(imags, -1, 2)
    if display:
        plt.figure(figsize=(12, 4))
        for i, data in enumerate(zip(reals, imags)):
            real, imag = data

            plt.subplot(2, 6, i + 1)
            plt.imshow(real, cmap="Spectral")
            plt.title(f"Real, Band{i+1}")
            plt.axis('off')

            plt.subplot(2, 6, i + 7)
            plt.imshow(imag, cmap="Spectral")
            plt.title(f"Imag, Band{i+1}")
            plt.axis('off')

        plt.suptitle(f"Level 1, Real and Imaginary Bands 1-6 {savepath}")

        if savepath != "":
            # directory = os.path.dirname(savepath)
            directory = '/mntdata/avanti/project/ece251c/op'
            plt.savefig(f"{directory}/{img_id}_bands.png")

        plt.show()

# %%
def get_patch_mean_variance(band, patch_size):
    H, W = band.shape
    patch_means = []
    for h in range(0, H, patch_size):
        for w in range(0, W, patch_size):
            patch = band[h:h+patch_size, w:w+patch_size]
            patch_means.append(np.mean(patch))

    var = np.var(patch_means)
    return var

# %%
def get_band_variance(mask, reals, imags, patch_size):
    real_var = []
    imag_var = []
    for real, imag in zip(reals, imags):
        # Real first
        band = mask * real
        real_var.append(get_patch_mean_variance(band, patch_size))
        
        # Imag
        band = mask * imag
        imag_var.append(get_patch_mean_variance(band, patch_size))

    return np.asarray(real_var), np.asarray(imag_var)

# %%
def compute_threshold_dynamic(mask, real_coeffs, imag_coeffs, patch_size):
    var_reals, var_imag = get_band_variance(mask, real_coeffs, imag_coeffs, patch_size)
    var = np.concatenate((var_imag, var_reals))
    var = np.percentile(var, 95)
    return var

# %% [markdown]
# # Wavelets

# %%
# Return the coeffs of the DT-CWT transform
def wavelet_dtcwt(img):
    assert len(img.shape) == 2, "Not a grayscale image"

    # Initialize the DTCWT transform
    transform = dtcwt.Transform2d()

    # Perform the DTCWT on the image with only 1 level
    coeffs = transform.forward(img, nlevels=1)
    return coeffs.highpasses[0]

# %%
def wavelet_general(img, wavelet_type='haar'):

    if wavelet_type == 'dtcwt':
        return wavelet_dtcwt(img)

    LL, (LH, HL, HH) = pywt.dwt2(img, wavelet_type)
    print(LH.shape)
    H, W = LH.shape

    coeffs = np.zeros((H, W, 3))
    coeffs[:, :, 0] = LH
    coeffs[:, :, 1] = HL
    coeffs[:, :, 2] = HH

    return coeffs

# %% [markdown]
# # Noise Models

# %%
def noise_zero(img):
    return np.zeros_like(img)

# %% [markdown]
# # Noise Variance Method

# %%
def im2patch(im, pch_size, stride=1):
    '''
    Transform image to patches.
    Input:
        im: 3 x H x W or 1 X H x W image, numpy format
        pch_size: (int, int) tuple or integer
        stride: (int, int) tuple or integer
    '''
    if isinstance(pch_size, tuple):
        pch_H, pch_W = pch_size
    elif isinstance(pch_size, int):
        pch_H = pch_W = pch_size
    else:
        print('The input of pch_size must be a integer or a int tuple!')

    if isinstance(stride, tuple):
        stride_H, stride_W = stride
    elif isinstance(stride, int):
        stride_H = stride_W = stride
    else:
        print('The input of stride must be a integer or a int tuple!')


    C, H, W = im.shape
    num_H = len(range(0, H-pch_H+1, stride_H))
    num_W = len(range(0, W-pch_W+1, stride_W))
    num_pch = num_H * num_W
    pch = np.zeros((C, pch_H*pch_W, num_pch), dtype=im.dtype)
    kk = 0
    for ii in range(pch_H):
        for jj in range(pch_W):
            temp = im[:, ii:H-pch_H+ii+1:stride_H, jj:W-pch_W+jj+1:stride_W]
            pch[:, kk, :] = temp.reshape((C, num_pch))
            kk += 1

    return pch.reshape((C, pch_H, pch_W, num_pch))

# %%
def noise_estimate(im, pch_size=8):
    '''
    Implement of noise level estimation of the following paper:
    Chen G , Zhu F , Heng P A . An Efficient Statistical Method for Image Noise Level Estimation[C]// 2015 IEEE International Conference
    on Computer Vision (ICCV). IEEE Computer Society, 2015.
    Input:
        im: the noise image, H x W x 3 or H x W numpy tensor, range [0,1]
        pch_size: patch_size
    Output:
        noise_level: the estimated noise level
    '''

    if im.ndim == 3:
        im = im.transpose((2, 0, 1))
    else:
        im = np.expand_dims(im, axis=0)

    # image to patch
    pch = im2patch(im, pch_size, 3)  # C x pch_size x pch_size x num_pch tensor
    num_pch = pch.shape[3]
    pch = pch.reshape((-1, num_pch))  # d x num_pch matrix
    d = pch.shape[0]

    mu = pch.mean(axis=1, keepdims=True)  # d x 1
    X = pch - mu
    sigma_X = np.matmul(X, X.transpose()) / num_pch
    sig_value, _ = np.linalg.eigh(sigma_X)
    sig_value.sort()

    for ii in range(-1, -d-1, -1):
        tau = np.mean(sig_value[:ii])
        if np.sum(sig_value[:ii]>tau) == np.sum(sig_value[:ii] < tau):
            return np.sqrt(tau)

# %% [markdown]
# # Filtering

# %%
# normalise the output between [0,1]
def small_median_filter_residue(band, kernel_size):
    median_blur = cv2.medianBlur(band, ksize=kernel_size)
    first_diff = band - median_blur
    second_diff = cv2.medianBlur(first_diff, ksize=kernel_size)
    band = band - second_diff
    band = (band - band.min()) / (band.max() - band.min())
    return band

# %%
def wiener_filter(band, kernel_size=3, noise_variance=0.1):
    local_mean = cv2.blur(band, (kernel_size, kernel_size))
    local_variance = cv2.blur((band - local_mean) ** 2, (kernel_size, kernel_size))
    wiener_filtered = local_mean + (local_variance - noise_variance) / (local_variance + 1e-8) * (band - local_mean)
    return np.clip(wiener_filtered, 0, 1)  # Clipping to avoid overflow

# %%
from skimage import restoration
from scipy.signal import convolve2d

# normalise the output between [0,1]
def wiener_filter_updated(img):
    psf = np.ones((5, 5)) / 25
    img = convolve2d(img, psf, 'same')
    rng = np.random.default_rng()
    img += 0.1 * img.std() * rng.standard_normal(img.shape)
    deconvolved_img = restoration.wiener(img, psf, 0.1)
    deconvolved_img = (deconvolved_img - deconvolved_img.min()) / (deconvolved_img.max() - deconvolved_img.min())
    return deconvolved_img

# %%
# normalise the output between [0,1]
def median_modified_wiener_filter(band, kernel_size=3, noise_variance=0.1):
    # Step 1: Apply median filter
    median_filtered = cv2.medianBlur(band, kernel_size)
    # Step 2: Apply Wiener filter to median-filtered band
    # wiener_filtered = wiener_filter(median_filtered, kernel_size, noise_variance)
    wiener_filtered = wiener_filter_updated(median_filtered)
    wiener_filtered = (wiener_filtered - wiener_filtered.min()) / (wiener_filtered.max() - wiener_filtered.min())
    return wiener_filtered

# %%
def get_mask_from_releavant_bands(bands, kernel_size, display=False):
    if len(bands) == 0:
        print("No bands available. Adjust threshold maybe.")
        return 0

    final_mask = np.zeros_like(bands[0])
    for band in bands:
        band = band.astype(np.float32)
        median_filtered = cv2.medianBlur(band, ksize=kernel_size)
        
        # normalise the output between [0,1]
        median_filtered = (median_filtered - median_filtered.min()) / (median_filtered.max() - median_filtered.min())

        smfr_filtered = small_median_filter_residue(band, kernel_size=kernel_size) 
        # wiener_filtered = wiener_filter(band, kernel_size=kernel_size)
        wiener_filtered = wiener_filter_updated(band)
        median_modified_wiener_filtered = median_modified_wiener_filter(band, kernel_size=kernel_size)

        # filters = [median_filtered, smfr_filtered, wiener_filtered, median_modified_wiener_filtered]
        filters = [median_filtered, smfr_filtered, wiener_filtered, median_modified_wiener_filtered]

        #display filtered images
        if display:
            plt.figure(figsize=(12, 4))
            for i, filter_img in enumerate(filters):
                filter_img_clipped = np.clip(filter_img, -1, 2)
                plt.subplot(1, 4, i + 1)
                plt.imshow(filter_img_clipped, cmap="Spectral")
                plt.title(f"Filter {i+1}")
                plt.axis('off')
                plt.colorbar()
            plt.suptitle("Filtered Images")
            plt.show()

        # noise estimate for the band 
        # largest_noise_estimate = noise_estimate(band, 8)

        avg_filter = np.zeros_like(median_filtered)
        for filter_img in filters:
            avg_filter += filter_img
        avg_filter /= len(filters)
        if display:
            avg_filter_clipped = np.clip(avg_filter, -1, 2)
            plt.imshow(avg_filter_clipped, cmap="Spectral")
            plt.title("Average Filter")
            plt.colorbar()
            plt.axis('off')
            plt.show()


        for filter_img in [avg_filter]:
            filtered_clusters = kmeans(filter_img, n_clusters=3, display=True)

            largest_noise_clus = None
            largest_noise_estimate = 1e-32
            # max_noise = -1e32
            for clus in list(np.unique(filtered_clusters)):
            #     internal_mask = (filtered_clusters == clus).astype(np.int8)
            #     noise = (band - filter_img) * internal_mask
            #     noise_range = noise.max() - noise.min()
                noise_est = noise_estimate(band, 8)
                if noise_est > largest_noise_estimate:
                    largest_noise_clus = clus
                    largest_noise_estimate = noise_est

            assert largest_noise_clus != None

            # display the lowest noise cluster
            if display:
                plt.imshow(filtered_clusters == largest_noise_clus)
                plt.title("Largest Noise Cluster")
                plt.colorbar()
                plt.axis('off')
                plt.show()

            final_mask += (filtered_clusters == largest_noise_clus).astype(np.int8)

    return final_mask

# %% [markdown]
# # Wrapper Function

# %%
def detect_inpainting(file_path, 
                      wavelet_type, 
                      noise_func, 
                      img_id,
                      loaded_detections,
                      patch_size=16, 
                      var_threshold='dynamic', 
                      kernel_size=3, 
                      segmentation_method='sam', 
                      display=False):
    # Read Image
    img = read_img(file_path)
    
    # Display Input Image
    if display:
        plt.imshow(img)
        plt.axis('off')
        plt.title("Input Image")
        plt.show()
        print("Image Shape ", img.shape)

    # Convert to grayscale
    gray_img = img.mean(axis=2)
    H, W = gray_img.shape

    # Display Gray Image
    if display:
        plt.imshow(gray_img, cmap="gray")
        plt.axis('off')
        plt.title("Gray Image")
        plt.show()

    # clusters = semantic_segmentation(img, n_clusters=1, display=True)
    clusters = None
    if segmentation_method == 'kmeans':
        clusters = simple_segmentation(img, n_clusters=4, feature_space='rgb', display=display, smoothing_sigma=1)
    elif segmentation_method == "sam":
        assert loaded_detections != None, "Loaded Detections are not passed"
        masks = loaded_detections["masks"]
        scores = loaded_detections["scores"]
        bounding_boxes = loaded_detections["bounding_boxes"]

        segments = np.zeros((H, W), dtype=int)

        for i, mask in enumerate(masks):
            # Ensure the mask is binary and within bounds
            mask = mask.astype(int)

            # Add the mask to the `segments` array with a unique label
            segments[mask == 1] = i + 1  # Use `i + 1` to avoid overlapping with background (0)

        # Perform segmentation
        clusters = segments
        plt.imshow(clusters, cmap="tab20")
        plt.axis('off')
        plt.title('Segmentation Result')
        plt.show()

    # TODO: Check if this is correct
    # We are W/2 and H/2 because the bands are of this size. But is this correct?
    # assert clusters != None
    clusters = clusters[::2, ::2]

    # Add Noise TODO: Check if this is the right place to add noise
    noise = noise_func(gray_img)
    gray_img += noise

    # DTCWT on grayscale image
    wavelet_coeffs = wavelet_general(gray_img, wavelet_type=wavelet_type) 
    print("Wavelet Coeffs Shape: ", wavelet_coeffs.shape)
    ##########################
    # IMPORTANT: wavelet_coeffs has to of the shape [H/2, W/2, bands]
    ##########################
    # assert wavelet_coeffs.shape == ((H+1)//2, (W+1)//2, 6), f"wavelet_coeffs is of shape: {wavelet_coeffs.shape}, but it's supposed to be {((H+1)//2, (W+1)//2, 6)}"

    # Normalize
    real_coeffs, imag_coeffs = normalize_coeffs(wavelet_coeffs)

    # Display Normalized and Clipped Wavelet Coefficients
    display_wavelet_coeffs(real_coeffs, imag_coeffs, img_id, display=display, savepath=file_path)

    final_mask = np.zeros_like(real_coeffs[0]) # TODO: Put correct shape here

    relavant_band_real = []
    relavant_band_imag = []

    for cluster in list(np.unique(clusters)):
        mask = (clusters == cluster).astype(np.int8)

        #pad the mask to make it equal to the size of the bands
        pad_x = (real_coeffs[0].shape[0] - mask.shape[0])
        pad_y = (real_coeffs[0].shape[1] - mask.shape[1])
        mask = np.pad(mask, ((pad_x//2, pad_x-(pad_x//2)), (pad_y//2, pad_y-(pad_y//2))), 'constant', constant_values=(0, 0))

        #display mask
        if display:
            plt.imshow(mask, cmap="gray")
            plt.axis('off')
            plt.title("Mask Image")
            plt.show()
        
        real_vars, imag_vars = get_band_variance(mask, real_coeffs, imag_coeffs, patch_size=patch_size)

        print("Real Vars: ", real_vars)
        print("Imag Vars: ", imag_vars)

        # if (np.all(real_vars < 1e-3) and np.all(imag_vars < 1e-3)):
        #     print("No relevant bands for this cluster found. Skipping...")
        #     continue

        real_vars_norm = (real_vars - real_vars.min()) / (real_vars.max() - real_vars.min())
        imag_vars_norm = (imag_vars - imag_vars.min()) / (imag_vars.max() - imag_vars.min())

        print("Real Vars Normalized: ", real_vars_norm)
        print("Imag Vars Normalized: ", imag_vars_norm)

        if var_threshold == 'dynamic':
            # var_threshold = compute_threshold_dynamic(mask, real_coeffs, imag_coeffs, patch_size)
            var_threshold_cluster = np.concatenate((real_vars_norm, imag_vars_norm))
            var_threshold_cluster = np.percentile(var_threshold_cluster, 95)

        print("Threshold: ", var_threshold_cluster)

        print("Picked Bands:")
        for i in range(len(real_vars_norm)):
            rvar, ivar = real_vars_norm[i], imag_vars_norm[i]

            if rvar >= var_threshold_cluster:
                relavant_band_real.append((mask * real_coeffs[i], real_vars[i]))
                print(f"Real {i+1}")

            if ivar >= var_threshold_cluster:
                relavant_band_imag.append((mask * imag_coeffs[i], imag_vars[i]))
                print(f"Imag {i+1}")

    # Get the list of variances of the bands
    var_list = [band[1] for band in relavant_band_real] + [band[1] for band in relavant_band_imag]
    var_percentile = np.percentile(var_list, 95)

    print("Releavant Bands", len(relavant_band_real), len(relavant_band_imag))

    # choose the top x percentile bands based on variance 
    relavant_band_real = [band for band in relavant_band_real if band[1] >= var_percentile]
    relavant_band_imag = [band for band in relavant_band_imag if band[1] >= var_percentile]

    #display the relevant bands
    if display:
        for i, band in enumerate(relavant_band_real):
            plt.imshow(band[0], cmap="Spectral")
            plt.title(f"Real Band {i+1}")
            plt.axis('off')
            plt.show()

        for i, band in enumerate(relavant_band_imag):
            plt.imshow(band[0], cmap="Spectral")
            plt.title(f"Imag Band {i+1}")
            plt.axis('off')
            plt.show()

    # Get the bands in a numpy array
    relavant_band_real = [band[0] for band in relavant_band_real]
    relavant_band_imag = [band[0] for band in relavant_band_imag]

    print("Final Releavant Bands", len(relavant_band_real), len(relavant_band_imag))
                
    final_mask += get_mask_from_releavant_bands(relavant_band_real, kernel_size=kernel_size, display=display)
    final_mask += get_mask_from_releavant_bands(relavant_band_imag, kernel_size=kernel_size, display=display)

      
    plt.imshow(final_mask, cmap="gray")
    plt.axis('off')
    plt.title("Final Mask")
    # directory = os.path.dirname(file_path)
    directory = '/mntdata/avanti/project/ece251c/op'
    plt.savefig(f"{directory}/{img_id}_final_mask_pre_morph.png")
    plt.show()

    return final_mask

# %%
pkl_folder = "/mntdata/lama_pkl"
img_folder = "/mntdata/avanti/Lama"

img_files = [f for f in os.listdir(img_folder) if f.endswith(('.bmp', '.png', '.jpg', '.jpeg'))]
pkl_files = [f for f in os.listdir(pkl_folder) if f.endswith('.pkl')]

# map unique identifiers to file paths
img_map = {os.path.splitext(img)[0]: os.path.join(img_folder, img) for img in img_files}
pkl_map = {os.path.splitext(pkl.replace('_filtered', ''))[0]: os.path.join(pkl_folder, pkl) for pkl in pkl_files}

for img_id, img_path in img_map.items():
    if img_id in pkl_map:  # match based on the unique identifier
        pkl_path = pkl_map[img_id]
        loaded_detections = None

        with open(pkl_path, "rb") as f:
            loaded_detections = pickle.load(f)
        
        final_mask = detect_inpainting(
            file_path=img_path,
            wavelet_type='dtcwt',
            img_id = img_id,
            noise_func=noise_zero,
            loaded_detections=loaded_detections,
            kernel_size=5,
            patch_size=64,
            var_threshold='dynamic',
            segmentation_method='sam',
            display=True
        )
        print(f"Processed {img_path} and {pkl_path}")
    else:
        print(f"No matching pickle found for {img_path}")


# loaded_detections = None
# with open("../lama.pkl", "rb") as f:
#     loaded_detections = pickle.load(f)
# final_mask = detect_inpainting(file_path="../lama.bmp", wavelet_type='dtcwt', noise_func=noise_zero, loaded_detections=loaded_detections, kernel_size=5, patch_size=64, var_threshold='dynamic', segmentation_method='kmeans', display=True)
# Out:
# No matching pickle found for /mntdata/avanti/Lama/66244a77636dd606_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0b2a2c061ef16759_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/415cd68440b0cc93_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/adb70973fa83d223_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a87aca1e7cedbff6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/28bd6c6b1050e055_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f1996864175ca4c2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/63594e96120c3f49_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7a7ad7084b691cd6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/84cdac98e44b5650_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2aa321ac42e0d5c4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/92c66476dc079909_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d63ab599cc1846b7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5b1c2d7b6864cc87_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a38ec06f797dfe08_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8b029ace6e7eff24_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5c70eafd580d8b7a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0274c6ca36923bbf_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1c6a06fd73646d9d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6dfde538c45623b4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/778082c38b13f711_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/57a7254dcf8e0b18_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/10050ae3c7122b14_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/23bf858cb1d0ef63_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b6a62420d8ab4160_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7da4e355186ce058_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c45570dd07cd7cc9_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6aac1291d2dac220_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5f0ff10a42ff4380_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8572129fbfc98cce_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/31989a8c33e4efd0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c4aacd3178b0f9f1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3928a399e08e1758_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/32a7bec333250f10_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2a53f4a7f1304cd6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/73265a6c10c3940a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c92b7a4d9d48926d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/12eb792a58304270_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/706b2b8fc80678ff_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b00b77542f28cb92_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4df808809bce3bef_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a5f2fd64daeb4792_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/782659036399c8e4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e18eb7705fbd3ed1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/adbb3cf376f76ad4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0b679ffe819c1799_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ccbbb8cf823c0a2c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3378d6c814c3994f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b779bf845522feeb_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/74c0ba867859baaf_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/201e6eb127ab48ac_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/62d100326bad961a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/215df3e72bb322c4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3d67b7c7f6a0ca2a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/09ac7b1e858b07a5_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/daa0af9634183b78_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c5977ff620d57d9f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f30cedac9b8aed01_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e2514ca55fd39e28_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a3ec122655eaa8fb_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/969676fe2534f17d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/433b06ff57834475_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/172254a20626b603_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0974243067d14bde_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/26a658f65dcb784b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ec6204dd25e4a71a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/03052f35d170935d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1ba2b5c1287de1cc_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a50864da0f1624c8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e19392fa12bd5d95_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e86add8b255211c8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/35ed0a188319981d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/82006cefa2e5fbad_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c33e197e59efc2bc_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/517d0bf8268fd589_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/12276881185e2251_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/95f1f7c069a97306_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/fefeea12c3751c06_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f60b675bb36e6fca_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/230d90f9c98d3044_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/23a6e02006eefe09_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9154d9c40eabea9a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/bebc48e7c898d552_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8d207f7ea5da29f1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a8caa841cf133945_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/14c70cfcc899ce63_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/44718b76bdbce255_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/76f4ea9994993053_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3215d07c3e72c5d2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/13b7206961bca9c6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/52115f7953b8173e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8193543a5af1a60a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/175ba13d56ecf95a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/87699183685865a2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/eb586148de2fbe3b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/abc0ab097170ece3_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3b36a27911aa8403_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4fa9c0522bd8c62c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2b0c7e98766e4d16_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/faf85f1d70b341f7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/45a8fd8fbdb5be00_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4bf20ac4061f4be0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/73991e5c3c0899e1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/91451da3dffef91f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/01cc041f0962d41c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/44c1659c072d1ac6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2da75f6335928609_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1fca4e8814de1ef8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/17f698ec871569ca_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9cea42d857941f46_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/cac1dc729748afff_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3b762b13ed78022d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ede26ed04594a26e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/db3b44b6711e7e2c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c5b5e27261da8f33_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8ba99e89ac316e63_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c3955eabb2b204ee_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/471337eb334dd3d0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/68c3071c9126e5d5_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f152e2dc82acf200_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/265c9966cf3408f6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/68b8bf926a0fbc7d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a753ebac051dfd6b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a4f33e0b7fb3f952_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ad41fd6ed69ed73a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/694fae862931296e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a8130a2ce38c9953_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/75301dc27dc64683_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/63996a04d4f8a550_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/cba62e6391b8d6e1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f7f53895cf4bf6d1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4483bbdd3241f11a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a5a9d237b04bc8fb_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a175a6c85643e38d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a53d205b2ad86b15_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/aadda77be1e8bc0b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3bc3a3b411a3624b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b3d471ee33c7d403_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6f30adffac250639_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/fb3fed6d3c8c3276_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/005589a94cadf725_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8d249edbf0471c4b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4c78cd030d7f408a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4be83f5eafd7398f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/cbd718027ebb4f52_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/23b43d43a750986c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a8117124ac8952d2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/66f8335ab51dd948_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/81bd27a53837f0ec_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/87ca03d4dd64798b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/fff3c65641e4925e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/77e32d1561fee28b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/252941bfee2147e3_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/597f27f1d0bb088a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/bee80cbc9d693793_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/036cf898c6176afd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d94649d81c0ddd56_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5339d7acea25b7ed_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/82397cd75822c942_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/dd49cf137ccc9707_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f9aedf7c8e3b586b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5506d91a9ac239b7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0675c64e78c43bd4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/47d14d071bcb8d11_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/015c309ce859052e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/bd1dbbc9508f71f6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5df435b817770857_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2c6d0a2a26c0488b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e4ac1e72ffae6a07_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b45f0e088ba581f2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/98fccbd3f882b3ce_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/141d8961e111ead7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7d8a18ad4ca79e06_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6905e899329b6088_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4ffe984820978979_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/43b6243cd8211888_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/88e4215a757b0778_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/42894a81eca95732_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/614c97c695a79926_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/cfbc6bcf50b73cbb_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/41805f88c840b506_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/daf18cd503e4fe05_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2a37405a99ec9c7c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/00f3addd05a6f8e8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d6208b5a2164b0ca_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/724da6ea76de07ae_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/76f84150a0ffb6f1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a34b2153902f8061_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/25f38efaf65a8ffd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/802bc0e99a203098_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7fa25536f608af03_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/160f58a67d2e290d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2ae7b29752f82465_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a72fd6303be85713_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/004a30a1ca460088_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ab08640f4ea3ba7f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9f8550843e6f1ba6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d49806c97051e011_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/455ffe9fb1a53786_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/427241fd00e40deb_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5396526cb47e235e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/446924d9efea3ada_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/de9f7b539744e041_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7048c5de3ffe1da8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/383f679fd7fe3445_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/85a8c309ae07dab6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c1e61b37a07c748f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/df65600fd6c81562_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f0322ebfe746d759_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1baa67b7a05a87c6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8bfb9b9e447e0397_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ea37bb8ce97f36d2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/172a979ab50c5a4e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0069e8be6d4f66f0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ac1247c30dd524de_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4150b5e0bc88f7ee_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8dc9e737e464866b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/015e65bb33ee3e0e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/09a2b6b7a21899b1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/808bf68b81c1b6ba_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a4d138e8ee63182a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3fbf3bd1c6910a78_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3ef096d4a5090512_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/dba4a819039e4f22_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1b009839e77f493d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/de5aecf60e2319d7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/48204f1b3007a6dc_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/95c0163a82377a78_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/73c0aa8688dbc51d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b572a2570265c6fa_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2fa4d728947841cd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f0de49cb319b79f6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/42d8cbf4d9dd1bb3_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/fc6fd707ddfdecc3_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/cab0106def50dd37_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a83d31d69e28914b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c518e3e659c2ebfc_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a9459cbecb699cec_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d75939dfc7c628cf_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/97c4c3df2b76945f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/457189afaa790204_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e1a2f9927ed71a90_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4ba04352857ebdcf_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e3caf236ec9848dd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9fe3dd8ad92d44f4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9b99ca7a0afc031c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4226aedbc485f6be_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3646df0b969235f4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ae4b5f936328666c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f63445d1e5247a6d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/59996cfdbbbeace9_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ceaf494efef3dfef_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a7022599a8e371cc_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f601ceded1bf3780_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/fc2477610db9edb0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4b54d4d3f2c7ccfd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d9b835b5f987eab5_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ba3853758c642077_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5be7cdc013e0dbb8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/93e44b278af70d94_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/226042dbf3ebdf47_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/22e1ff1caab930d7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/912c06afe1099c5d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5611b201a7e56931_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a317e67e628b0e9a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6bcbb7a4cdc162f3_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/final_mask_pre_morph.png
# No matching pickle found for /mntdata/avanti/Lama/aea45ba75eb06f5c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f12683c9889fcd1d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/eb83425a3a67e9fb_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9ce92a930c97a9fa_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/774a20234749713f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5dd2bfa81252538b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3147a98fde9e8e0e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/835f500b4f18425a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c900d676c0c5de3a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/528219663af7c0d2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/04ec76a53c18a44b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/cc627ec7e5dbbb6e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8c1c686c3e02f1d5_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/862da80c3c69cf22_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/834a8a69bd737987_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b88953006dce138e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/22f3edfa092f010e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/afe829d19eba1f5a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1f93eb9aceeaf52e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3226f563d30d7129_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/fa9c1a8fa79456a4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/55a3e2b8816056fa_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/309132ed1ba67786_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1194132584fa4ba2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/63b4de1130a1ce25_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/673aece0c899d7bc_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a30b783d5a0fa64f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/dc5e1e33c26e410c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/55d3576d4da19c99_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/98bf8042df9dd4c0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5090acd79151e5d2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ed280425a08b288a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b3dcd8151b798534_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4dbe0d526f7f9bf0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3d77555f2ede0b38_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b7849521e3d68761_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c55eb21a055cc44c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5a35b6662ee93a7f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/469ae737247d3e1b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/40adb7cb1e71790f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/614490ee351f4528_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/59e512825446956e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4b0e03d60349ead4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0438c2d3613680bf_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/97d3fdcbe826e032_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7bc500661f0ea2c7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f41d7d3ebcf88d10_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/eb860406ae9b661b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/01d831fbda6fa27e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d48b994023e536d0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/244341868bbfe84d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6b88736131a2328b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/eef11a77f38bde5f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e3769db5f70fe96c_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1f310eafba136cb6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/420d128acb5b6215_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/318a33e0fe1774a5_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/a9eb0ef18a2e58d2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5cbd93b52ca7e949_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/890a08ff48bf62d8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c10d956a07834f59_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/47f118de6a3212fb_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6374fa68a043bb0f_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/50af10820920446e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4468b40b69625dce_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5d7479b5a42f5f0e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7ab575b8b0392c3d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/89a44017a3abe974_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4dde84abe3b984ff_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ef7d8527d2b810d8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8f5f50aeb8658083_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4d211ac255f269a6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/df611c466bf70c7a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0d2c5b1589550b25_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/5be8fe2fc78d4388_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f6c5f644d5b8cfc4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1fd97b32298d03ae_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/87ea58fb7ed13387_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d80fa1bfdd6d4e8a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/69444449be0d216e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ab495e2ac0be4176_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/47fcf6dd408f4a00_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7053ad0ed8118c44_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/bc857cdddd5c152e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/989a9e23660a2f26_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/338205d9092742f4_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/d923596ed64ae2b6_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1cf3197242e16924_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f42d79953a8622cd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/bands.png
# No matching pickle found for /mntdata/avanti/Lama/0f8403aa92381a18_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/571b5eecff5600dc_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/36296aefe846a82e_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7ce97122f0e27d28_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ab0be1741d742eba_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0b19ea3376871338_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/48b32a631b8f954b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/68e544cf109dfd86_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/1a70014e04f0422b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/87ce9b0a7a589e99_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9b237883ded9f898_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/19737c8bfc0b06b9_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3a11b0dcb9c29aa2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/44a1c33f790c5687_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e9476d72513acbc1_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f0b478c8e7044174_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/874b055e396f73fd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/aa9b35d1bee25627_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b07d9761a2fc0ca7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ad2da9f2e631ce58_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/8fa5ad9fc2178522_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b013ed5aad9c00d7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/05ca3422aa670ef0_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/039beb511fd1e7f7_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e2fe509e3a83fcce_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/9722a92ac4eaf3f3_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c966cb21efa54558_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/c2300fca4873e364_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/b9e5c3663ff1839a_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/878bb252666780c9_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/3faa503009c70368_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/429306aefd95f8a8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/f4830b273c9dd521_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/ac1590f2e07e201b_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/6faa48fd26fbe582_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/339686bfa60a0ad2_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/02682a455ece74dd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/e1981c43ae256d7d_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/4a87a57e8401efdf_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/0c4e291e151205c8_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/56a1e9f45b126934_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/44615bece0a97866_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/2b748f85a4fe0eb3_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/7ba9f066de0921fd_altered.bmp
# No matching pickle found for /mntdata/avanti/Lama/28c76d0a7af641d1_altered.bmp

# %%
def morph_mask(mask):
    # use cv2 to fill the holes
    mask = mask.astype(np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))

    # do opening and closing to remove small noise
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))

    # remove big connected components from the white mask
    mask = morphology.remove_small_objects(mask > 0, min_size=64, connectivity=1).astype(np.uint8)

    # invert the mask and remove small connected components from the black mask and invert it back
    mask = 1 - mask
    mask = morphology.remove_small_objects(mask > 0, min_size=512, connectivity=1).astype(np.uint8)
    mask = 1 - mask

    # open the mask to remove small noise
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))

    return mask


mask = morph_mask(final_mask)
plt.imshow(mask, cmap="gray")
plt.axis('off')
plt.title("Filled Mask")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 24
#      19     mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))
#      21     return mask
# ---> 24 mask = morph_mask(final_mask)
#      25 plt.imshow(mask, cmap="gray")
#      26 plt.axis('off')
#
# NameError: name 'final_mask' is not defined

# %% [markdown]
# # Metrics

# %%
def calculate_metrics(gt_mask, pred_mask, threshold=0.5):
    # Convert predicted mask to numpy array
    pred_mask = np.array(pred_mask)
    
    # Ensure both masks have the same shape
    if gt_mask.shape != pred_mask.shape:
        raise ValueError("Ground truth and predicted masks must have the same shape.")
    
    # Convert masks to boolean arrays
    gt_mask_bool = gt_mask > threshold
    pred_mask_bool = pred_mask > threshold
    
    # Calculate intersection and union
    intersection = np.logical_and(gt_mask_bool, pred_mask_bool)
    union = np.logical_or(gt_mask_bool, pred_mask_bool)
    
    # Calculate IoU
    union_sum = np.sum(union)
    iou = np.sum(intersection) / union_sum if union_sum > 0 else 1.0
    
    # Calculate accuracy
    accuracy = np.mean(gt_mask_bool == pred_mask_bool)
    
    # Calculate precision and recall
    true_positive = np.sum(intersection)
    false_positive = np.sum(np.logical_and(~gt_mask_bool, pred_mask_bool))
    false_negative = np.sum(np.logical_and(gt_mask_bool, ~pred_mask_bool))
    
    precision = true_positive / (true_positive + false_positive) if (true_positive + false_positive) > 0 else 1.0
    recall = true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 1.0
    
    # Calculate F1 score
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
    
    return {
        "accuracy": accuracy,
        "iou": iou,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score,
    }

# # get the ground truth mask
# gt_mask = read_img("/mntdata/avanti/project/ece251c/md_0_paper_mask.png")
# print(gt_mask)

# # downsample the ground truth mask to match the predicted mask size
# gt_mask = gt_mask[::2, ::2]
# gt_mask = gt_mask.mean(axis=2)

# print("Ground Truth Mask Shape: ", gt_mask.shape)

# # print the ground truth mask
# plt.imshow(gt_mask, cmap="gray")
# plt.axis('off')
# plt.title("Ground Truth Mask")
# plt.show()

# # calculate the quality metrics
# metrics = calculate_metrics(gt_mask, morphed_mask)
# print(metrics)
# # print(f"Accuracy: {accuracy:.4f}")
# # print(f"IoU: {iou:.4f}")

# %% [markdown]
# # Experiments

# %%
data_dir = "../project/data/test"
overall_accuracy, overall_iou = calculate_overall_metrics(data_dir, wavelet_type='dtcwt', noise_func=noise_zero, kernel_size=3, patch_size=16, var_threshold=0.005)
print(f"Overall Accuracy: {overall_accuracy:.4f}")
print(f"Overall IoU: {overall_iou:.4f}")

# %% [markdown]
# # Pipeline To Run All Images and Wavelets

# %%
wavelets = ['dtcwt', 'haar', 'sym2', 'db2', 'coif2']

src_path = ""
img_folders = []                # TODO: Get all the images from the source folder

result_path = ""
metrics = [["File Path", "Wavelet", "Accuracy", "IOU", "Precision", "Recall", "F1 score"]]


for f in img_folders:
    img_path = None             # TODO: set img path
    mask = None                 # TODO: read mask
    pickle_filepath = None      # TODO: set pickle filepath

    loaded_detections = None
    with open(pickle_filepath, "rb") as f:
        loaded_detections = pickle.load(f)

    for wavelet in wavelets:
        # Get output mask
        output_mask = detect_inpainting(
            file_path=img_path, 
            wavelet_type=wavelet, 
            noise_func=noise_zero, 
            loaded_detections=loaded_detections, 
            patch_size=64, 
            var_threshold='dynamic', 
            kernel_size=5, 
            segmentation_method='sam', 
            display=False)
        
        output_mask = morph_mask(output_mask)

        im = Image.fromarray(output_mask)
        im.save(f"{f}/final_mask.jpg")

        # Compute Metrics on it
        computed_metrics = calculate_metrics(mask, output_mask, threshold=0.5)
        computed_metrics = [img_path, wavelet] + [value for value in computed_metrics.values()]

        metrics.append(computed_metrics)


with open(result_path, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(metrics)

print(f"Data saved to {result_path}")
